# %% [markdown]
# Quizz 1. Forest fires

# %%
#import the libraries
import numpy as np
import pandas as pd
#titles for graphs
from IPython.display import display, Markdown

# %%
#import the csv
df = pd.read_csv("forestfires.csv")

# %%
def title(text):
    display(Markdown(f'### {text}'))

#let's get basic info about the data
title('Overview')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
display(df)        # first and last 5 rows - get a feel for the data

title('Statistics')
display(df.describe())    # stats for numeric columns (mean, min, max...)

title('Info')
df.info()                 # column types + non-null counts

title('Nulls per column')
nulls = df.isnull().sum()
display(nulls[nulls > 0])               # null count per column


title('Duplicate Rows')
display(df.duplicated().sum())          # number of duplicate rows
display(df[df.duplicated(keep=False)]) # show duplicate rows


title('Distinct Values per Column')
display(df.nunique())                   # distinct values per column

title('Correlation Matrix')
corr_matrix = df.corr(numeric_only=True)

mask = (corr_matrix.abs() >= 0.5) & ~np.eye(len(corr_matrix), dtype=bool)
filtered = corr_matrix.where(mask).dropna(how='all').dropna(axis=1, how='all')

display(filtered.fillna(''))
# Out:
# ### Overview
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]
# ### Statistics
# ...

# %% [markdown]
# Q3. Target is burned surface which is column "area".
# There's 12 predictive variables and 1 target.

# %% [markdown]
# # Done with Quizz 1
